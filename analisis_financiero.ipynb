# %%
import yfinance as yf
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objs as go

# %% [markdown]
# # Análisis financiero: Evolución en la tasa de conversión de la moneda de Píses Sudamericano frente al Dólar Estadounidense durante los últimos 20 Años
#
# ### Autor: Renzo Reyna
#
# #### Analista de Datos
#
# ### website: https://www.desarrolladorsarmientino.com
#
# #### Fuente de datos: Yahoo Finance

# %%
start= datetime.datetime(2000, 5, 25)
end= datetime.datetime(2024, 5, 25)

# %%
# Lectura de datos para el peso Argentino
ars_value = yf.download('ARSUSD=X', start=start, end=end)
print(ars_value.head(6))
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2001-07-13  0.998004  1.000700  1.000500  1.000600   1.000600       0
# 2001-07-16  0.998004  1.001502  1.001001  1.001252   1.001252       0
# 2001-07-23  0.998004  1.001402  1.001202  1.001302   1.001302       0
# 2001-07-30  0.998004  1.002004  1.001502  1.001753   1.001753       0
# 2001-08-06  0.998004  1.001402  1.001302  1.001352   1.001352       0
# 2001-08-13  0.998004  0.998502  0.997506  1.001151   1.001151       0

# %%
df_ars= pd.DataFrame(ars_value)

df_ars.reset_index(inplace= True)

df_ars
# Out:
#            Date      Open      High       Low     Close  Adj Close  Volume
# 0    2001-07-13  0.998004  1.000700  1.000500  1.000600   1.000600       0
# 1    2001-07-16  0.998004  1.001502  1.001001  1.001252   1.001252       0
# 2    2001-07-23  0.998004  1.001402  1.001202  1.001302   1.001302       0
# 3    2001-07-30  0.998004  1.002004  1.001502  1.001753   1.001753       0
# 4    2001-08-06  0.998004  1.001402  1.001302  1.001352   1.001352       0
# ...         ...       ...       ...       ...       ...        ...     ...
# 5399 2024-05-20  0.001132  0.001133  0.001125  0.001132   0.001132       0
# 5400 2024-05-21  0.001125  0.001125  0.001124  0.001125   0.001125       0
# 5401 2024-05-22  0.001125  0.001125  0.001124  0.001125   0.001125       0
# 5402 2024-05-23  0.001124  0.001124  0.001123  0.001124   0.001124       0
# 5403 2024-05-24  0.001123  0.001124  0.001123  0.001123   0.001123       0
#
# [5404 rows x 7 columns]

# %%
df_ars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5404 entries, 0 to 5403
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5404 non-null   datetime64[ns]
#  1   Open       5404 non-null   float64
#  2   High       5404 non-null   float64
#  3   Low        5404 non-null   float64
#  4   Close      5404 non-null   float64
#  5   Adj Close  5404 non-null   float64
#  6   Volume     5404 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 295.7 KB

# %%
df_argentina= df_ars[['Date', 'Close']]

df_argentina= df_argentina.copy()

# %%
df_argentina.rename(columns={'Date':'Período analizado', 'Close':'Valor de conversión'}, inplace=True)

df_argentina
# Out:
#      Período analizado  Valor de conversión
# 0           2001-07-13             1.000600
# 1           2001-07-16             1.001252
# 2           2001-07-23             1.001302
# 3           2001-07-30             1.001753
# 4           2001-08-06             1.001352
# ...                ...                  ...
# 5399        2024-05-20             0.001132
# 5400        2024-05-21             0.001125
# 5401        2024-05-22             0.001125
# 5402        2024-05-23             0.001124
# 5403        2024-05-24             0.001123
#
# [5404 rows x 2 columns]

# %%
#Crear gráfico para tasa de conversión del peso Argentino a Dólares USD 
sns.set_theme(style="whitegrid")

sns.lineplot(data=df_argentina, x="Período analizado", y="Valor de conversión", linewidth=1)

plt.title("Valor del Peso Argentino en USD")

plt.show()

print("Tasa de conversión promedio del Peso Argentino durante el período analizado:", np.mean(df_argentina["Valor de conversión"]))
# Out:
# Tasa de conversión promedio del Peso Argentino durante el período analizado: 0.16462343445859973

# %%
# Lectura de Datos para moneda de brasil
bra_value= yf.download('BRLUSD=X', start=start, end=end)
print(bra_value.head(6))
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2003-12-01  0.339443  0.342114  0.339443  0.342114   0.342114       0
# 2003-12-02  0.342114  0.342114  0.341180  0.341180   0.341180       0
# 2003-12-03  0.341180  0.341763  0.340599  0.341180   0.341180       0
# 2003-12-04  0.341180  0.341180  0.339789  0.339789   0.339789       0
# 2003-12-05  0.339789  0.340832  0.339213  0.340832   0.340832       0
# 2003-12-08  0.340832  0.340832  0.339789  0.340136   0.340136       0

# %%
df_brl= pd.DataFrame(bra_value)

df_brl.reset_index(inplace= True)

df_brl
# Out:
#            Date      Open      High       Low     Close  Adj Close  Volume
# 0    2003-12-01  0.339443  0.342114  0.339443  0.342114   0.342114       0
# 1    2003-12-02  0.342114  0.342114  0.341180  0.341180   0.341180       0
# 2    2003-12-03  0.341180  0.341763  0.340599  0.341180   0.341180       0
# 3    2003-12-04  0.341180  0.341180  0.339789  0.339789   0.339789       0
# 4    2003-12-05  0.339789  0.340832  0.339213  0.340832   0.340832       0
# ...         ...       ...       ...       ...       ...        ...     ...
# 4893 2024-05-20  0.196002  0.196886  0.195046  0.196002   0.196002       0
# 4894 2024-05-21  0.195959  0.196793  0.195633  0.195959   0.195959       0
# 4895 2024-05-22  0.195240  0.196688  0.193750  0.195240   0.195240       0
# 4896 2024-05-23  0.194133  0.195868  0.193964  0.194133   0.194133       0
# 4897 2024-05-24  0.194435  0.194974  0.194001  0.194435   0.194435       0
#
# [4898 rows x 7 columns]

# %%
df_brl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4898 non-null   datetime64[ns]
#  1   Open       4898 non-null   float64
#  2   High       4898 non-null   float64
#  3   Low        4898 non-null   float64
#  4   Close      4898 non-null   float64
#  5   Adj Close  4898 non-null   float64
#  6   Volume     4898 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 268.0 KB

# %%
df_brasil= df_brl[['Date', 'Close']]

df_brasil= df_brasil.copy()

# %%
df_brasil.rename(columns={'Date':'Período analizado', 'Close':'Valor de conversión'}, inplace=True)

# %%
# Crear gráfico para tasa de cambio de la moneda de brasil en Dólares USD
sns.set_theme(style="whitegrid")

sns.lineplot(data=df_brasil, x="Período analizado", y="Valor de conversión", linewidth=1)

plt.title("Valor del Real en USD")

plt.show()

print("Tasa de conversión promedio del Real durante el período analizado:", np.mean(df_brasil["Valor de conversión"]))
# Out:
# Tasa de conversión promedio del Real durante el período analizado: 0.37208097355068337

# %%
uyu_value= yf.download('UYUUSD=X', start=start, end=end)
print(uyu_value.head(6))
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2002-04-01  0.064103  0.064935  0.063291  0.064041   0.064041       0
# 2002-07-29  0.040984  0.042373  0.039293  0.041068   0.041068       0
# 2002-07-30  0.039960  0.039960  0.039801  0.039880   0.039880       0
# 2003-01-02  0.036769  0.036832  0.036496  0.036530   0.036530       0
# 2003-04-21  0.035069  0.035162  0.035039  0.035131   0.035131       0
# 2003-12-01  0.035073  0.035073  0.035073  0.035073   0.035073       0

# %%
df_uyu= pd.DataFrame(uyu_value)

df_uyu.reset_index(inplace= True)

df_uyu
# Out:
#            Date      Open      High       Low     Close  Adj Close  Volume
# 0    2002-04-01  0.064103  0.064935  0.063291  0.064041   0.064041       0
# 1    2002-07-29  0.040984  0.042373  0.039293  0.041068   0.041068       0
# 2    2002-07-30  0.039960  0.039960  0.039801  0.039880   0.039880       0
# 3    2003-01-02  0.036769  0.036832  0.036496  0.036530   0.036530       0
# 4    2003-04-21  0.035069  0.035162  0.035039  0.035131   0.035131       0
# ...         ...       ...       ...       ...       ...        ...     ...
# 5330 2024-05-20  0.026275  0.026275  0.026131  0.026324   0.026324       0
# 5331 2024-05-21  0.026128  0.026339  0.026128  0.026124   0.026124       0
# 5332 2024-05-22  0.026319  0.026393  0.026319  0.026339   0.026339       0
# 5333 2024-05-23  0.026377  0.026490  0.026377  0.026393   0.026393       0
# 5334 2024-05-24  0.026405  0.026405  0.026351  0.026490   0.026490       0
#
# [5335 rows x 7 columns]

# %%
df_uyu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5335 entries, 0 to 5334
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5335 non-null   datetime64[ns]
#  1   Open       5335 non-null   float64
#  2   High       5335 non-null   float64
#  3   Low        5335 non-null   float64
#  4   Close      5335 non-null   float64
#  5   Adj Close  5335 non-null   float64
#  6   Volume     5335 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 291.9 KB

# %%
df_uruguay= df_uyu[['Date', 'Close']]

df_uruguay= df_uruguay.copy()

# %%
df_uruguay.rename(columns={'Date':'Período analizado', 'Close':'Valor de conversión'}, inplace=True)

# %%
sns.set_theme(style="whitegrid")

sns.lineplot(data=df_uruguay, x="Período analizado", y="Valor de conversión", linewidth=1)

plt.title("Valor del Peso Uruguayo en USD")

plt.show()

print("Tasa de conversión promedio de Peso Uruguayo durante el período analizado:", np.mean(df_uruguay["Valor de conversión"]))
# Out:
# Tasa de conversión promedio de Peso Uruguayo durante el período analizado: 0.03846520624789492

# %%
chile_value= yf.download('CLPUSD=X', start=start, end=end)
print(chile_value.head(6))
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2003-12-01  0.001590  0.001590  0.001590  0.001657   0.001657       0
# 2003-12-02  0.001676  0.001676  0.001676  0.001676   0.001676       0
# 2003-12-03  0.001683  0.001683  0.001683  0.001683   0.001683       0
# 2003-12-04  0.001713  0.001713  0.001713  0.001713   0.001713       0
# 2003-12-05  0.001700  0.001700  0.001700  0.001700   0.001700       0
# 2003-12-08  0.001647  0.001647  0.001647  0.001647   0.001647       0

# %%
df_cl= pd.DataFrame(chile_value)

df_cl.reset_index(inplace= True)

df_cl
# Out:
#            Date      Open      High       Low     Close  Adj Close  Volume
# 0    2003-12-01  0.001590  0.001590  0.001590  0.001657   0.001657       0
# 1    2003-12-02  0.001676  0.001676  0.001676  0.001676   0.001676       0
# 2    2003-12-03  0.001683  0.001683  0.001683  0.001683   0.001683       0
# 3    2003-12-04  0.001713  0.001713  0.001713  0.001713   0.001713       0
# 4    2003-12-05  0.001700  0.001700  0.001700  0.001700   0.001700       0
# ...         ...       ...       ...       ...       ...        ...     ...
# 5305 2024-05-20  0.001119  0.001130  0.001119  0.001119   0.001119       0
# 5306 2024-05-21  0.001127  0.001128  0.001123  0.001127   0.001127       0
# 5307 2024-05-22  0.001126  0.001126  0.001114  0.001126   0.001126       0
# 5308 2024-05-23  0.001113  0.001116  0.001098  0.001113   0.001113       0
# 5309 2024-05-24  0.001100  0.001106  0.001099  0.001100   0.001100       0
#
# [5310 rows x 7 columns]

# %%
df_chile= df_cl[['Date', 'Close']]

df_chile= df_chile.copy()

# %%
df_chile.rename(columns={'Date':'Período analizado','Close':'Valor de conversión'}, inplace=True)

# %%
sns.set_theme(style="whitegrid")

sns.lineplot(data=df_chile, x="Período analizado", y="Valor de conversión", linewidth=1)

plt.title("Valor delPeso Chileno en USD")

plt.show()

print("Tasa de conversión promedio del Peso Chileno durante el período analizado:", np.mean(df_chile["Valor de conversión"]))
# Out:
# Tasa de conversión promedio del Peso Chileno durante el período analizado: 0.001737857531379512

# %%
guarani_value= yf.download('PYGUSD=X', start=start, end=end)
print(guarani_value.head(6))
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2003-12-01  0.000167  0.000167  0.000167  0.000167   0.000167       0
# 2003-12-02  0.000167  0.000167  0.000167  0.000167   0.000167       0
# 2003-12-03  0.000167  0.000167  0.000167  0.000167   0.000167       0
# 2003-12-04  0.000166  0.000166  0.000166  0.000166   0.000166       0
# 2003-12-05  0.000166  0.000166  0.000166  0.000166   0.000166       0
# 2003-12-08  0.000167  0.000167  0.000167  0.000167   0.000167       0

# %%
df_guarani= pd.DataFrame(guarani_value)

df_guarani.reset_index(inplace= True)

df_guarani
# Out:
#            Date      Open      High       Low     Close  Adj Close  Volume
# 0    2003-12-01  0.000167  0.000167  0.000167  0.000167   0.000167       0
# 1    2003-12-02  0.000167  0.000167  0.000167  0.000167   0.000167       0
# 2    2003-12-03  0.000167  0.000167  0.000167  0.000167   0.000167       0
# 3    2003-12-04  0.000166  0.000166  0.000166  0.000166   0.000166       0
# 4    2003-12-05  0.000166  0.000166  0.000166  0.000166   0.000166       0
# ...         ...       ...       ...       ...       ...        ...     ...
# 5299 2024-05-20  0.000136  0.000136  0.000136  0.000136   0.000136       0
# 5300 2024-05-21  0.000136  0.000136  0.000135  0.000136   0.000136       0
# 5301 2024-05-22  0.000135  0.000135  0.000135  0.000135   0.000135       0
# 5302 2024-05-23  0.000135  0.000135  0.000135  0.000135   0.000135       0
# 5303 2024-05-24  0.000135  0.000135  0.000135  0.000135   0.000135       0
#
# [5304 rows x 7 columns]

# %%
df_paraguay= df_guarani[['Date', 'Close']]

df_paraguay= df_paraguay.copy()

# %%
df_paraguay.rename(columns={'Date':'Período analizado', 'Close':'Valor de conversión'}, inplace=True)

# %%
sns.set_theme(style="whitegrid")

sns.lineplot(data=df_paraguay, x="Período analizado", y="Valor de conversión", linewidth=1)

plt.title("Valor del Guaraní en USD")

plt.show()

print("Tasa de conversión promedio del Guaraní durante el período analizado:", np.mean(df_paraguay["Valor de conversión"]))
# Out:
# Tasa de conversión promedio del Guaraní durante el período analizado: 0.00018913655238266265

# %%
bol_value= yf.download('BOBUSD=X', start=start, end=end)
print(bol_value.head(6))
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2002-04-01  0.142258  0.142389  0.142126  0.142258   0.142258       0
# 2003-01-02  0.133333  0.133449  0.133218  0.133333   0.133333       0
# 2003-04-21  0.131484  0.131631  0.131320  0.131449   0.131449       0
# 2003-12-01  0.131977  0.131977  0.131977  0.131977   0.131977       0
# 2003-12-02  0.132175  0.132175  0.132175  0.132175   0.132175       0
# 2003-12-03  0.131846  0.131846  0.131846  0.131846   0.131846       0

# %%
df_bol= pd.DataFrame(bol_value)

df_bol.reset_index(inplace= True)

df_bol
# Out:
#            Date      Open      High       Low     Close  Adj Close  Volume
# 0    2002-04-01  0.142258  0.142389  0.142126  0.142258   0.142258       0
# 1    2003-01-02  0.133333  0.133449  0.133218  0.133333   0.133333       0
# 2    2003-04-21  0.131484  0.131631  0.131320  0.131449   0.131449       0
# 3    2003-12-01  0.131977  0.131977  0.131977  0.131977   0.131977       0
# 4    2003-12-02  0.132175  0.132175  0.132175  0.132175   0.132175       0
# ...         ...       ...       ...       ...       ...        ...     ...
# 5302 2024-05-20  0.149193  0.149193  0.148561  0.149479   0.149479       0
# 5303 2024-05-21  0.148543  0.148648  0.148543  0.148519   0.148519       0
# 5304 2024-05-22  0.148540  0.148599  0.148540  0.148648   0.148648       0
# 5305 2024-05-23  0.148516  0.148682  0.148516  0.148599   0.148599       0
# 5306 2024-05-24  0.148205  0.148621  0.148205  0.148682   0.148682       0
#
# [5307 rows x 7 columns]

# %%
df_bolivia= df_bol[['Date', 'Close']]

df_bolivia= df_bolivia.copy()

df_bolivia.rename(columns={'Date':'Período analizado', 'Close':'Valor de conversión'}, inplace=True)

# %%
sns.set_theme(style="whitegrid")

sns.lineplot(data=df_bolivia, x="Período analizado", y="Valor de conversión", linewidth=1)

plt.title("Valor del Peso Boliviano en USD")

plt.show()

print("Tasa de conversión promedio del Peso Boliviano durante el período analizado:", np.mean(df_bolivia["Valor de conversión"]))
# Out:
# Tasa de conversión promedio del Peso Boliviano durante el período analizado: 0.14364914594676864

# %%
sol_value= yf.download('PENUSD=X', start=start, end=end)
print(sol_value.head(6))
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2001-05-31  0.276014  0.276014  0.276014  0.276014   0.276014       0
# 2001-06-01  0.276014  0.276014  0.276014  0.276014   0.276014       0
# 2001-06-04  0.276014  0.276014  0.276014  0.276014   0.276014       0
# 2001-06-05  0.276014  0.276014  0.276014  0.276014   0.276014       0
# 2001-06-06  0.276014  0.276014  0.276014  0.276014   0.276014       0
# 2001-06-07  0.276014  0.276014  0.276014  0.276014   0.276014       0

# %%
df_sol= pd.DataFrame(sol_value)

df_sol.reset_index(inplace= True)

df_sol
# Out:
#            Date      Open      High       Low     Close  Adj Close  Volume
# 0    2001-05-31  0.276014  0.276014  0.276014  0.276014   0.276014       0
# 1    2001-06-01  0.276014  0.276014  0.276014  0.276014   0.276014       0
# 2    2001-06-04  0.276014  0.276014  0.276014  0.276014   0.276014       0
# 3    2001-06-05  0.276014  0.276014  0.276014  0.276014   0.276014       0
# 4    2001-06-06  0.276014  0.276014  0.276014  0.276014   0.276014       0
# ...         ...       ...       ...       ...       ...        ...     ...
# 5986 2024-05-20  0.274612  0.274083  0.267308  0.274612   0.274612       0
# 5987 2024-05-21  0.272624  0.272669  0.267881  0.272624   0.272624       0
# 5988 2024-05-22  0.268097  0.273051  0.268097  0.268097   0.268097       0
# 5989 2024-05-23  0.268025  0.273330  0.272891  0.268025   0.268025       0
# 5990 2024-05-24  0.267380  0.272754  0.267165  0.267380   0.267380       0
#
# [5991 rows x 7 columns]

# %%
df_peru= df_sol[['Date', 'Close']]

df_peru= df_peru.copy()

df_peru.rename(columns={'Date':'Período analizado', 'Close':'Valor de conversión'}, inplace=True)

# %%
sns.set_theme(style="whitegrid")

sns.lineplot(data=df_peru, x="Período analizado", y="Valor de conversión", linewidth=1)

plt.title("Valor del Sol Peruano en USD")

plt.show()

print("Tasa de conversión promedio del Sol Peruano durante el período analizado:", np.mean(df_peru["Valor de conversión"]))
# Out:
# Tasa de conversión promedio del Sol Peruano durante el período analizado: 0.314945650917026

# %% [markdown]
# # Evolución de la tasa de conversión de monedas de Países que conforman el Bloque Económico (MERCOSUR)

# %%
fig= go.Figure()

fig.add_trace(go.Scatter(x=df_argentina['Período analizado'], y=df_argentina['Valor de conversión'], name='Peso Argentino'))
fig.add_trace(go.Scatter(x=df_brasil['Período analizado'], y=df_brasil['Valor de conversión'], name='Real Brasileño'))
fig.add_trace(go.Scatter(x=df_paraguay['Período analizado'], y=df_paraguay['Valor de conversión'], name='Guaraní Paraguay'))
fig.add_trace(go.Scatter(x=df_uruguay['Período analizado'], y=df_uruguay['Valor de conversión'], name='Peso Uruguayo'))

fig.update_layout(title='Evolución en la tasa de conversión entre los Países que conforman el bloque económico (MERCOSUR)',
                   xaxis_title='Período analizado',
                   yaxis_title='Valor de conversión (USD)',
                   plot_bgcolor='white',                    
                 )

fig.add_annotation(
    text="www.desarrolladorsarmientino.com",
    xref="paper",  # Referencia al eje x (puedes ajustar según tus necesidades)
    yref="paper",  # Referencia al eje y (puedes ajustar según tus necesidades)
    x=0.5,  # Posición horizontal (0.5 está en el centro)
    y=-0.24,  # Posición vertical (negativo para estar debajo del gráfico)
    showarrow=False,  # Sin flecha de conexión
    font=dict(size=12)  # Tamaño de fuente (ajusta según tu preferencia)
)

fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='#999999')
fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='#999999')


fig.show()
# Out:
# <div>                            <div id="036a594a-6e2c-45f4-820a-142cc4af9b37" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("036a594a-6e2c-45f4-820a-142cc4af9b37")) {                    Plotly.newPlot(                        "036a594a-6e2c-45f4-820a-142cc4af9b37",                        [{"name":"Peso Argentino","x":["2001-07-13T00:00:00","2001-07-16T00:00:00","2001-07-23T00:00:00","2001-07-30T00:00:00","2001-08-06T00:00:00","2001-08-13T00:00:00","2001-08-20T00:00:00","2001-08-27T00:00:00","2001-09-03T00:00:00","2001-09-10T00:00:00","2002-04-01T00:00:00","2002-04-08T00:00:00","2002-04-11T00:00:00","2002-04-15T00:00:00","2002-04-17T00:00:00","2002-04-22T00:00:00","2002-04-29T00:00:00","2002-05-06T00:00:00","2002-05-13T00:00:00","2002-05-20T00:00:00","2002-05-27T00:00:00","2002-06-03T00:00:00","2002-06-10T00:00:00","2002-06-17T00:00:00","2002-06-24T00:00:00","2002-07-01T00:00:00","2002-07-08T00:00:00","2002-07-12T00:00:00","2002-07-15T00:00:00","2002-07-22T00:00:00","2002-07-29T00:00:00","2002-08-05T00:00:00","2002-08-12T00:00:00","2002-08-19T00:00:00","2002-08-26T00:00:00","2002-09-02T00:00:00","2002-09-09T00:00:00","2002-09-16T00:00:00","2002-09-30T00:00:00","2002-10-07T00:00:00","2002-10-14T00:00:00","2002-10-21T00:00:00","2002-10-28T00:00:00","2002-11-04T00:00:00","2002-11-11T00:00:00","2002-11-13T00:00:00","2002-11-14T00:00:00","2002-11-18T00:00:00","2002-11-25T00:00:00","2002-12-02T00:00:00","2002-12-09T00:00:00","2002-12-16T00:00:00","2002-12-23T00:00:00","2002-12-27T00:00:00","2002-12-30T00:00:00","2003-01-02T00:00:00","2003-01-06T00:00:00","2003-01-13T00:00:00","2003-01-20T00:00:00","2003-01-27T00:00:00","2003-02-03T00:00:00","2003-02-10T00:00:00","2003-02-17T00:00:00","2003-02-24T00:00:00","2003-03-03T00:00:00","2003-03-05T00:00:00","2003-03-10T00:00:00","2003-03-12T00:00:00","2003-03-17T00:00:00","2003-03-24T00:00:00","2003-03-31T00:00:00","2003-04-07T00:00:00","2003-04-14T00:00:00","2003-04-21T00:00:00","2003-04-28T00:00:00","2003-12-01T00:00:00","2003-12-02T00:00:00","2003-12-03T00:00:00","2003-12-04T00:00:00","2003-12-05T00:00:00","2003-12-08T00:00:00","2003-12-09T00:00:00","2003-12-10T00:00:00","2003-12-11T00:00:00","2003-12-12T00:00:00","2003-12-15T00:00:00","2003-12-16T00:00:00","2003-12-17T00:00:00","2003-12-18T00:00:00","2003-12-19T00:00:00","2003-12-22T00:00:00","2003-12-23T00:00:00","2003-12-29T00:00:00","2003-12-30T00:00:00","2003-12-31T00:00:00","2004-01-02T00:00:00","2004-01-05T00:00:00","2004-01-06T00:00:00","2004-01-07T00:00:00","2004-01-08T00:00:00","2004-01-09T00:00:00","2004-01-12T00:00:00","2004-01-13T00:00:00","2004-01-14T00:00:00","2004-01-15T00:00:00","2004-01-16T00:00:00","2004-01-19T00:00:00","2004-01-20T00:00:00","2004-01-21T00:00:00","2004-01-22T00:00:00","2004-01-23T00:00:00","2004-01-26T00:00:00","2004-01-27T00:00:00","2004-01-28T00:00:00","2004-01-29T00:00:00","2004-01-30T00:00:00","2004-02-02T00:00:00","2004-02-03T00:00:00","2004-02-04T00:00:00","2004-02-05T00:00:00","2004-02-06T00:00:00","2004-02-09T00:00:00","2004-02-10T00:00:00","2004-02-11T00:00:00","2004-02-12T00:00:00","2004-02-13T00:00:00","2004-02-16T00:00:00","2004-02-17T00:00:00","2004-02-18T00:00:00","2004-02-19T00:00:00","2004-02-20T00:00:00","2004-02-23T00:00:00","2004-02-24T00:00:00","2004-02-25T00:00:00","2004-02-26T00:00:00","2004-02-27T00:00:00","2004-03-01T00:00:00","2004-03-02T00:00:00","2004-03-03T00:00:00","2004-03-04T00:00:00","2004-03-05T00:00:00","2004-03-08T00:00:00","2004-03-09T00:00:00","2004-03-10T00:00:00","2004-03-11T00:00:00","2004-03-12T00:00:00","2004-03-15T00:00:00","2004-03-16T00:00:00","2004-03-17T00:00:00","2004-03-18T00:00:00","2004-03-19T00:00:00","2004-03-22T00:00:00","2004-03-23T00:00:00","2004-03-24T00:00:00","2004-03-25T00:00:00","2004-03-26T00:00:00","2004-0 ...
